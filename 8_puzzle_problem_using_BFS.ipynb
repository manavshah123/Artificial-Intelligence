# %% [markdown]
# <a href="https://colab.research.google.com/github/manavshah123/Artificial-Intelligence/blob/main/8_puzzle_problem_using_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 8 puzzle
import enum
import time


class Action(enum.Enum):
    MoveDown = 1
    MoveUp = 2
    MoveLeft = 3
    MoveRight = 4
    NoAction = 0


class Node:
    def __init__(self, position: [], parent: None, action: Action.NoAction):
        self.position = position  # [1, 2, 3, 0, 4, 6, 7, 5, 8]  # scan
        self.h = 0
        self.f = 0
        self.parent = parent
        self.action = action

    def __eq__(self, other):
        return self.position == other.position

    def __lt__(self, other):
        return self.f < other.f

    def __repr__(self):
        return '\n'.join(
            [str(self.action), str(self.position[:3]), str(self.position[3:6]), str(self.position[6:9])]).replace("[",
                                                                                                                  "").replace(
            ']',
            '').replace(
            ',', '').replace('0', '_')

    def _h(self, goal):
        return sum([1 if self.position[i] != goal.position[i] else 0 for i in range(8)])

    def generatevalue(self, goal):
        self.h = self._h(goal)
        self.f = self.h

    def possibleMoves(self):
        successors = []
        i = self.position.index(0)

        # move down
        if i in [3, 4, 5, 6, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 3] = new_value[i - 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveDown))

        # move top
        if i in [0, 1, 2, 3, 4, 5]:
            new_value = self.position[:]
            new_value[i], new_value[i + 3] = new_value[i + 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveUp))

        # move left
        if i in [0, 1, 3, 4, 6, 7]:
            new_value = self.position[:]
            new_value[i], new_value[i + 1] = new_value[i + 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveLeft))

        # move right
        if i in [1, 2, 4, 5, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 1] = new_value[i - 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveRight))

        return successors


def Best_FS(initial_node, Goal_Node):
    Open_list = []
    Close_list = []
    Open_list.append(initial_node)
    while len(Open_list) > 0:
        Open_list.sort()
        currentNode = Open_list.pop(0)
        Close_list.append(currentNode)
        if currentNode == Goal_Node:
            # return Close_list  # path
            path = []
            while currentNode != initial_node:
                path.append(currentNode)
                currentNode = currentNode.parent
            return path[::-1]
        all_successors = currentNode.possibleMoves()
        for i in all_successors:
            if i in Close_list:
                continue
            i.generatevalue(Goal_Node)
            if can_add_to_open(Open_list, i):
                Open_list.append(i)


def can_add_to_open(Open_list, successors):
    for i in Open_list:
        if i == successors and successors.f >= i.f:
            return False
    return True


initial_node = Node([1, 2, 3, 0, 4, 6, 7, 5, 8], None, Action.NoAction)
currentNode = initial_node
Goal_Node = Node([1, 2, 3, 4, 5, 6, 7, 8, 0], None, Action.NoAction)
print(Goal_Node)
start_time = time.time()
path = Best_FS(initial_node, Goal_Node)
End_time = time.time()
for i in path:
    print(i)
print("Path Cost=", len(path) - 1)

print("Execution time=", (End_time - start_time) * 1000, "ms")
# Out:
# Action.NoAction
# 1 2 3
# 4 5 6
# 7 8 _
# Action.MoveLeft
# 1 2 3
# 4 _ 6
# 7 5 8
# Action.MoveUp
# 1 2 3
# 4 5 6
# 7 _ 8
# Action.MoveLeft
# 1 2 3
# 4 5 6
# 7 8 _
# Path Cost= 2
# Execution time= 0.11444091796875 ms

# %%
# 8 puzzle
import enum
import time


class Action(enum.Enum):
    MoveDown = 1
    MoveUp = 2
    MoveLeft = 3
    MoveRight = 4
    NoAction = 0


class Node:
    def __init__(self, position: [], parent: None, action: Action.NoAction):
        self.position = position  # [1, 2, 3, 0, 4, 6, 7, 5, 8]  # scan
        self.h = 0
        self.f = 0
        self.parent = parent
        self.action = action

    def __eq__(self, other):
        return self.position == other.position

    def __lt__(self, other):
        return self.f < other.f

    def __repr__(self):
        return '\n'.join(
            [str(self.action), str(self.position[:3]), str(self.position[3:6]), str(self.position[6:9])]).replace("[",
                                                                                                                  "").replace(
            ']',
            '').replace(
            ',', '').replace('0', '_')

    def _h(self, goal):
        return sum([1 if self.position[i] != goal.position[i] else 0 for i in range(8)])

    def generatevalue(self, goal):
        self.h = self._h(goal)
        self.f = self.h

    def possibleMoves(self):
        successors = []
        i = self.position.index(0)

        # move down
        if i in [3, 4, 5, 6, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 3] = new_value[i - 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveDown))

        # move top
        if i in [0, 1, 2, 3, 4, 5]:
            new_value = self.position[:]
            new_value[i], new_value[i + 3] = new_value[i + 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveUp))

        # move left
        if i in [0, 1, 3, 4, 6, 7]:
            new_value = self.position[:]
            new_value[i], new_value[i + 1] = new_value[i + 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveLeft))

        # move right
        if i in [1, 2, 4, 5, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 1] = new_value[i - 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveRight))

        return successors


def Best_FS(initial_node, Goal_Node):
    Open_list = []
    Close_list = []
    Open_list.append(initial_node)
    while len(Open_list) > 0:
        Open_list.sort()
        currentNode = Open_list.pop(0)
        Close_list.append(currentNode)
        if currentNode == Goal_Node:
            # return Close_list  # path
            path = []
            while currentNode != initial_node:
                path.append(currentNode)
                currentNode = currentNode.parent
            return path[::-1]
        all_successors = currentNode.possibleMoves()
        for i in all_successors:
            if i in Close_list:
                continue
            i.generatevalue(Goal_Node)
            if can_add_to_open(Open_list, i):
                Open_list.append(i)


def can_add_to_open(Open_list, successors):
    for i in Open_list:
        if i == successors and successors.f >= i.f:
            return False
    return True


initial_node = Node([2, 8, 3, 1, 6, 4, 7, 0, 5], None, Action.NoAction)
currentNode = initial_node
Goal_Node = Node([1, 2, 3, 8, 0, 4, 7, 6, 5], None, Action.NoAction)
print(Goal_Node)
start_time = time.time()
path = Best_FS(initial_node, Goal_Node)
End_time = time.time()
for i in path:
    print(i)
print("Path Cost=", len(path) - 1)

print("Execution time=", (End_time - start_time) * 1000, "ms")
# Out:
# Action.NoAction
# 1 2 3
# 8 _ 4
# 7 6 5
# Action.MoveDown
# 2 8 3
# 1 _ 4
# 7 6 5
# Action.MoveDown
# 2 _ 3
# 1 8 4
# 7 6 5
# Action.MoveRight
# _ 2 3
# 1 8 4
# 7 6 5
# Action.MoveUp
# 1 2 3
# _ 8 4
# 7 6 5
# Action.MoveLeft
# 1 2 3
# 8 _ 4
# 7 6 5
# Path Cost= 4
# Execution time= 0.14662742614746094 ms

# %%
# 8 puzzle
import enum
import time


class Action(enum.Enum):
    MoveDown = 1
    MoveUp = 2
    MoveLeft = 3
    MoveRight = 4
    NoAction = 0


class Node:
    def __init__(self, position: [], parent: None, action: Action.NoAction):
        self.position = position  # [1, 2, 3, 0, 4, 6, 7, 5, 8]  # scan
        self.h = 0
        self.f = 0
        self.parent = parent
        self.action = action

    def __eq__(self, other):
        return self.position == other.position

    def __lt__(self, other):
        return self.f < other.f

    def __repr__(self):
        return '\n'.join(
            [str(self.action), str(self.position[:3]), str(self.position[3:6]), str(self.position[6:9])]).replace("[",
                                                                                                                  "").replace(
            ']',
            '').replace(
            ',', '').replace('0', '_')

    def _h(self, goal):
        return sum([1 if self.position[i] != goal.position[i] else 0 for i in range(8)])

    def generatevalue(self, goal):
        self.h = self._h(goal)
        self.f = self.h

    def possibleMoves(self):
        successors = []
        i = self.position.index(0)

        # move down
        if i in [3, 4, 5, 6, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 3] = new_value[i - 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveDown))

        # move top
        if i in [0, 1, 2, 3, 4, 5]:
            new_value = self.position[:]
            new_value[i], new_value[i + 3] = new_value[i + 3], new_value[i]
            successors.append(Node(new_value, self, Action.MoveUp))

        # move left
        if i in [0, 1, 3, 4, 6, 7]:
            new_value = self.position[:]
            new_value[i], new_value[i + 1] = new_value[i + 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveLeft))

        # move right
        if i in [1, 2, 4, 5, 7, 8]:
            new_value = self.position[:]
            new_value[i], new_value[i - 1] = new_value[i - 1], new_value[i]
            successors.append(Node(new_value, self, Action.MoveRight))

        return successors


def Best_FS(initial_node, Goal_Node):
    Open_list = []
    Close_list = []
    Open_list.append(initial_node)
    while len(Open_list) > 0:
        Open_list.sort()
        currentNode = Open_list.pop(0)
        Close_list.append(currentNode)
        if currentNode == Goal_Node:
            # return Close_list  # path
            path = []
            while currentNode != initial_node:
                path.append(currentNode)
                currentNode = currentNode.parent
            return path[::-1]
        all_successors = currentNode.possibleMoves()
        for i in all_successors:
            if i in Close_list:
                continue
            i.generatevalue(Goal_Node)
            if can_add_to_open(Open_list, i):
                Open_list.append(i)


def can_add_to_open(Open_list, successors):
    for i in Open_list:
        if i == successors and successors.f >= i.f:
            return False
    return True


initial_node = Node([3, 0, 7, 2, 8, 1, 6, 4, 5], None, Action.NoAction)
currentNode = initial_node
Goal_Node = Node([1, 2, 3, 4, 5, 6, 7, 8, 0], None, Action.NoAction)
print(Goal_Node)
start_time = time.time()
path = Best_FS(initial_node, Goal_Node)
End_time = time.time()
for i in path:
    print(i)
print("Path Cost=", len(path) - 1)

print("Execution time=", (End_time - start_time) * 1000, "ms")
# Out:
# Action.NoAction
# 1 2 3
# 4 5 6
# 7 8 _
# Action.MoveUp
# 3 8 7
# 2 _ 1
# 6 4 5
# Action.MoveUp
# 3 8 7
# 2 4 1
# 6 _ 5
# Action.MoveRight
# 3 8 7
# 2 4 1
# _ 6 5
# Action.MoveDown
# 3 8 7
# _ 4 1
# 2 6 5
# Action.MoveLeft
# 3 8 7
# 4 _ 1
# 2 6 5
# Action.MoveDown
# 3 _ 7
# 4 8 1
# 2 6 5
# Action.MoveLeft
# 3 7 _
# 4 8 1
# 2 6 5
# Action.MoveUp
# 3 7 1
# 4 8 _
# 2 6 5
# Action.MoveUp
# 3 7 1
# 4 8 5
# 2 6 _
# Action.MoveRight
# 3 7 1
# 4 8 5
# 2 _ 6
# Action.MoveDown
# 3 7 1
# 4 _ 5
# 2 8 6
# Action.MoveLeft
# 3 7 1
# 4 5 _
# 2 8 6
# Action.MoveDown
# 3 7 _
# 4 5 1
# 2 8 6
# Action.MoveRight
# 3 _ 7
# 4 5 1
# 2 8 6
# Action.MoveUp
# 3 5 7
# 4 _ 1
# 2 8 6
# Action.MoveLeft
# 3 5 7
# 4 1 _
# 2 8 6
# Action.MoveUp
# 3 5 7
# 4 1 6
# 2 8 _
# Action.MoveRight
# 3 5 7
# 4 1 6
# 2 _ 8
# Action.MoveDown
# 3 5 7
# 4 _ 6
# 2 1 8
# Action.MoveDown
# 3 _ 7
# 4 5 6
# 2 1 8
# Action.MoveRight
# _ 3 7
# 4 5 6
# 2 1 8
# Action.MoveUp
# 4 3 7
# _ 5 6
# 2 1 8
# Action.MoveUp
# 4 3 7
# 2 5 6
# _ 1 8
# Action.MoveLeft
# 4 3 7
# 2 5 6
# 1 _ 8
# Action.MoveLeft
# 4 3 7
# 2 5 6
# 1 8 _
# Action.MoveDown
# 4 3 7
# 2 5 _
# 1 8 6
# Action.MoveDown
# 4 3 _
# 2 5 7
# 1 8 6
# Action.MoveRight
# 4 _ 3
# 2 5 7
# 1 8 6
# Action.MoveUp
# 4 5 3
# 2 _ 7
# 1 8 6
# Action.MoveRight
# 4 5 3
# _ 2 7
# 1 8 6
# Action.MoveDown
# _ 5 3
# 4 2 7
# 1 8 6
# Action.MoveLeft
# 5 _ 3
# 4 2 7
# 1 8 6
# Action.MoveUp
# 5 2 3
# 4 _ 7
# 1 8 6
# Action.MoveLeft
# 5 2 3
# 4 7 _
# 1 8 6
# Action.MoveUp
# 5 2 3
# 4 7 6
# 1 8 _
# Action.MoveRight
# 5 2 3
# 4 7 6
# 1 _ 8
# Action.MoveDown
# 5 2 3
# 4 _ 6
# 1 7 8
# Action.MoveRight
# 5 2 3
# _ 4 6
# 1 7 8
# Action.MoveUp
# 5 2 3
# 1 4 6
# _ 7 8
# Action.MoveLeft
# 5 2 3
# 1 4 6
# 7 _ 8
# Action.MoveDown
# 5 2 3
# 1 _ 6
# 7 4 8
# Action.MoveDown
# 5 _ 3
# 1 2 6
# 7 4 8
# Action.MoveRight
# _ 5 3
# 1 2 6
# 7 4 8
# Action.MoveUp
# 1 5 3
# _ 2 6
# 7 4 8
# Action.MoveLeft
# 1 5 3
# 2 _ 6
# 7 4 8
# Action.MoveUp
# 1 5 3
# 2 4 6
# 7 _ 8
# Action.MoveRight
# 1 5 3
# 2 4 6
# _ 7 8
# Action.MoveDown
# 1 5 3
# _ 4 6
# 2 7 8
# Action.MoveLeft
# 1 5 3
# 4 _ 6
# 2 7 8
# Action.MoveDown
# 1 _ 3
# 4 5 6
# 2 7 8
# Action.MoveRight
# _ 1 3
# 4 5 6
# 2 7 8
# Action.MoveUp
# 4 1 3
# _ 5 6
# 2 7 8
# Action.MoveUp
# 4 1 3
# 2 5 6
# _ 7 8
# Action.MoveLeft
# 4 1 3
# 2 5 6
# 7 _ 8
# Action.MoveDown
# 4 1 3
# 2 _ 6
# 7 5 8
# Action.MoveRight
# 4 1 3
# _ 2 6
# 7 5 8
# Action.MoveDown
# _ 1 3
# 4 2 6
# 7 5 8
# Action.MoveLeft
# 1 _ 3
# 4 2 6
# 7 5 8
# Action.MoveUp
# 1 2 3
# 4 _ 6
# 7 5 8
# Action.MoveUp
# 1 2 3
# 4 5 6
# 7 _ 8
# Action.MoveLeft
# 1 2 3
# 4 5 6
# 7 8 _
# Path Cost= 60
# Execution time= 53.038835525512695 ms
